# %%
import pandas as pd
import numpy as np
import folium
import json

# %%
from pyproj import Proj

zone_number = 33

def convert_dd_to_utm(latitude, longitude):

    if latitude == 0 or longitude == 0:
        return 0,0

    # Definisci la proiezione UTM
    utm_proj = Proj(proj='utm', zone=zone_number, ellps='WGS84')

    # Effettua la conversione delle coordinate
    utm_easting, utm_northing = utm_proj(longitude, latitude)

    return utm_easting, utm_northing

# %%
df = pd.read_csv("/content/converted_misa_24112023_pos_2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3556 entries, 0 to 3555
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3556 non-null   int64
#  1   latitude_2   3556 non-null   float64
#  2   longitude_2  3556 non-null   float64
#  3   PDOP         3556 non-null   float64
#  4   utm_east     3556 non-null   float64
#  5   utm_north    3556 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 166.8 KB

# %%
df.head()
# Out:
#    Unnamed: 0  latitude_2  longitude_2  PDOP       utm_east     utm_north
# 0           0    0.000000     0.000000  0.00       0.000000  0.000000e+00
# 1           1   43.721143    13.221362  2.09  356732.024810  4.842439e+06
# 2           2   43.721137    13.221343  2.09  356730.440568  4.842438e+06
# 3           3   43.721125    13.221320  2.09  356728.597988  4.842437e+06
# 4           4   43.721119    13.221307  2.09  356727.551543  4.842436e+06

# %%
df.rename(columns = {'Unnamed: 0' : "index_campione"})
# Out:
#       index_campione  latitude_2  longitude_2  PDOP       utm_east  \
# 0                  0    0.000000     0.000000   0.0       0.000000
# 1                  1   43.721378    13.221035   4.3  356706.204812
# 2                  2   43.721377    13.221035   4.3  356706.229278
# 3                  3   43.721376    13.221035   4.3  356706.241511
# 4                  4   43.721376    13.221035   4.3  356706.240716
# ...              ...         ...          ...   ...            ...
# 2868            2868   43.721190    13.221181   1.3  356717.582881
# 2869            2869   43.721190    13.221181   1.3  356717.556826
# 2870            2870   43.721190    13.221180   1.3  356717.517345
# 2871            2871   43.721190    13.221180   1.3  356717.504715
# 2872            2872   43.721191    13.221180   1.3  356717.478659
#
#          utm_north
# 0     0.000000e+00
# 1     4.842465e+06
# 2     4.842465e+06
# 3     4.842465e+06
# 4     4.842465e+06
# ...            ...
# 2868  4.842444e+06
# 2869  4.842444e+06
# 2870  4.842444e+06
# 2871  4.842444e+06
# 2872  4.842444e+06
#
# [2873 rows x 6 columns]

# %%
df_1 = df[183:212].copy()
df_2 = df[947:976].copy()
df_3 = df[989:1018].copy()
df_4 = df[1235:1264].copy()
df_5 = df[1992:2021].copy()
df_6 = df[2033:2062].copy()
df_7 = df[2275:2304].copy()

# %%
df_7
# Out:
#       Unnamed: 0  latitude_2  longitude_2  PDOP       utm_east     utm_north
# 2275        2275   43.721156    13.221258   1.9  356723.664333  4.842440e+06
# 2276        2276   43.721159    13.221260   1.9  356723.846805  4.842441e+06
# 2277        2277   43.721159    13.221261   1.9  356723.913930  4.842441e+06
# 2278        2278   43.721159    13.221261   1.9  356723.954603  4.842441e+06
# 2279        2279   43.721159    13.221262   1.9  356724.008303  4.842441e+06
# 2280        2280   43.721159    13.221263   1.9  356724.062003  4.842441e+06
# 2281        2281   43.721159    13.221263   1.9  356724.088853  4.842441e+06
# 2282        2282   43.721159    13.221263   1.9  356724.128731  4.842441e+06
# 2283        2283   43.721159    13.221263   1.9  356724.128731  4.842441e+06
# 2284        2284   43.721159    13.221264   1.9  356724.195857  4.842441e+06
# 2285        2285   43.721159    13.221265   1.9  356724.221912  4.842441e+06
# 2286        2286   43.721159    13.221266   1.9  356724.302463  4.842441e+06
# 2287        2287   43.721159    13.221266   1.9  356724.329313  4.842441e+06
# 2288        2288   43.721159    13.221267   1.9  356724.369588  4.842441e+06
# 2289        2289   43.721159    13.221267   1.9  356724.409466  4.842441e+06
# 2290        2290   43.721158    13.221267   1.9  356724.435919  4.842441e+06
# 2291        2291   43.721158    13.221268   1.8  356724.462769  4.842441e+06
# 2292        2292   43.721158    13.221268   1.8  356724.462769  4.842441e+06
# 2293        2293   43.721158    13.221269   1.8  356724.529894  4.842441e+06
# 2294        2294   43.721158    13.221269   1.8  356724.556744  4.842441e+06
# 2295        2295   43.721158    13.221269   1.9  356724.570169  4.842441e+06
# 2296        2296   43.721158    13.221269   1.9  356724.570169  4.842441e+06
# 2297        2297   43.721158    13.221270   1.9  356724.610445  4.842441e+06
# 2298        2298   43.721158    13.221270   1.9  356724.610445  4.842441e+06
# 2299        2299   43.721158    13.221270   2.3  356724.637295  4.842441e+06
# 2300        2300   43.721158    13.221270   3.3  356724.637295  4.842441e+06
# 2301        2301   43.721159    13.221270   3.3  356724.651117  4.842441e+06
# 2302        2302   43.721159    13.221270   3.3  356724.677967  4.842441e+06
# 2303        2303   43.721159    13.221270   3.3  356724.691790  4.842441e+06

# %% [markdown]
# #registrazione 1

# %%
mean_1_ll = [np.mean(df_1["latitude_2"]), np.mean(df_1["longitude_2"])]
median_1_ll = [ np.median(df_1["latitude_2"]), np.median(df_1["longitude_2"])]

east,north = convert_dd_to_utm(mean_1_ll[0],mean_1_ll[1])
mean_1_utm = [east,north]
east,north = convert_dd_to_utm(median_1_ll[0],median_1_ll[1])
median_1_utm = [east,north]
variance_1_utm = [ np.var(df_1["utm_east"]), np.var(df_1["utm_north"]) ]

pdop_mean_1 = np.mean(df_1["PDOP"])

map_1 = folium.Map(location=[df_1["latitude_2"].iloc[0], df_1["longitude_2"].iloc[0]], zoom_start=18)

#for x in zip(df_2["latitude_2"].to_list(), df_1["longitude_2"].to_list()):
  #print(x)
#  folium.Marker(location = x, popup = x).add_to(map_1)

folium.Marker(location = mean_1_ll, tooltip= "mean", icon=folium.Icon(color="red")).add_to(map_1)
folium.Marker(location = median_1_ll, tooltip= "median", icon=folium.Icon(color="black")).add_to(map_1)


map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a32987c0f735028bcb2afae2cf9e2574 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a32987c0f735028bcb2afae2cf9e2574&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a32987c0f735028bcb2afae2cf9e2574 = L.map(
#                 &quot;map_a32987c0f735028bcb2afae2cf9e2574&quot;,
#                 {
#                     center: [43.72146333333333, 13.220948666666668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7eed7f600a84f79c0f550e54bbc09057 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a32987c0f735028bcb2afae2cf9e2574);
#
#
#             var marker_5ec27103867c86fc61caaa4aa2b01760 = L.marker(
#                 [43.72141913218391, 13.220938063218396],
#                 {}
#             ).addTo(map_a32987c0f735028bcb2afae2cf9e2574);
#
#
#             var icon_20e4d3b2ce0271353fb5cb2fbc9bbc08 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5ec27103867c86fc61caaa4aa2b01760.setIcon(icon_20e4d3b2ce0271353fb5cb2fbc9bbc08);
#
#
#             marker_5ec27103867c86fc61caaa4aa2b01760.bindTooltip(
#                 `&lt;div&gt;
#                      mean
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1935526807f13b87fdc0ae9825fb4595 = L.marker(
#                 [43.72141966666667, 13.220942833333334],
#                 {}
#             ).addTo(map_a32987c0f735028bcb2afae2cf9e2574);
#
#
#             var icon_27078f16e5dea7db5b0b1c550cbfb0bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1935526807f13b87fdc0ae9825fb4595.setIcon(icon_27078f16e5dea7db5b0b1c550cbfb0bc);
#
#
#             marker_1935526807f13b87fdc0ae9825fb4595.bindTooltip(
#                 `&lt;div&gt;
#                      median
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #Registrazione 2

# %%
mean_2_ll = [np.mean(df_2["latitude_2"]), np.mean(df_2["longitude_2"])]
median_2_ll = [ np.median(df_2["latitude_2"]), np.median(df_2["longitude_2"])]

east,north = convert_dd_to_utm(mean_2_ll[0],mean_2_ll[1])
mean_2_utm = [east,north]
east,north = convert_dd_to_utm(median_2_ll[0],median_2_ll[1])
median_2_utm = [east,north]
variance_2_utm = [ np.var(df_2["utm_east"]), np.var(df_2["utm_north"]) ]

pdop_mean_2 = np.mean(df_2["PDOP"])

map_2 = folium.Map(location=[df_1["latitude_2"].iloc[0], df_1["longitude_2"].iloc[0]], zoom_start=18)

#for x in zip(df_2["latitude_2"].to_list(), df_1["longitude_2"].to_list()):
  #print(x)
#  folium.Marker(location = x, popup = x).add_to(map_1)

folium.Marker(location = mean_2_ll, tooltip= "mean", icon=folium.Icon(color="red")).add_to(map_2)
folium.Marker(location = median_2_ll, tooltip= "median", icon=folium.Icon(color="black")).add_to(map_2)


map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b07dd531de3b4bca5a5bf330a2e56c08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b07dd531de3b4bca5a5bf330a2e56c08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b07dd531de3b4bca5a5bf330a2e56c08 = L.map(
#                 &quot;map_b07dd531de3b4bca5a5bf330a2e56c08&quot;,
#                 {
#                     center: [43.72146333333333, 13.220948666666668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_361cc6f2aeff2f6619d8c7016ffa86c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b07dd531de3b4bca5a5bf330a2e56c08);
#
#
#             var marker_edb7f75b0b1a9d61fa76614e97f6883d = L.marker(
#                 [43.721179206896544, 13.221290120689659],
#                 {}
#             ).addTo(map_b07dd531de3b4bca5a5bf330a2e56c08);
#
#
#             var icon_c79016aaa1584c5a8eeee120215e2b64 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_edb7f75b0b1a9d61fa76614e97f6883d.setIcon(icon_c79016aaa1584c5a8eeee120215e2b64);
#
#
#             marker_edb7f75b0b1a9d61fa76614e97f6883d.bindTooltip(
#                 `&lt;div&gt;
#                      mean
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_35e8c10fecbe342351f99693d1727779 = L.marker(
#                 [43.72117933333333, 13.22129],
#                 {}
#             ).addTo(map_b07dd531de3b4bca5a5bf330a2e56c08);
#
#
#             var icon_630965df5d0675fd3b5898691c46ded8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_35e8c10fecbe342351f99693d1727779.setIcon(icon_630965df5d0675fd3b5898691c46ded8);
#
#
#             marker_35e8c10fecbe342351f99693d1727779.bindTooltip(
#                 `&lt;div&gt;
#                      median
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #Registrazione 3

# %%
mean_3_ll = [np.mean(df_3["latitude_2"]), np.mean(df_3["longitude_2"])]
median_3_ll = [ np.median(df_3["latitude_2"]), np.median(df_3["longitude_2"])]

east,north = convert_dd_to_utm(mean_3_ll[0],mean_3_ll[1])
mean_3_utm = [east,north]
east,north = convert_dd_to_utm(median_3_ll[0],median_3_ll[1])
median_3_utm = [east,north]
variance_3_utm = [ np.var(df_3["utm_east"]), np.var(df_3["utm_north"]) ]

pdop_mean_3 = np.mean(df_3["PDOP"])

map_3 = folium.Map(location=[df_1["latitude_2"].iloc[0], df_1["longitude_2"].iloc[0]], zoom_start=18)

#for x in zip(df_2["latitude_2"].to_list(), df_1["longitude_2"].to_list()):
  #print(x)
#  folium.Marker(location = x, popup = x).add_to(map_1)

folium.Marker(location = mean_3_ll, tooltip= "mean", icon=folium.Icon(color="red")).add_to(map_3)
folium.Marker(location = median_3_ll, tooltip= "median", icon=folium.Icon(color="black")).add_to(map_3)


map_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da3dc3cfb5cce4a58a118181cd0fcc4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da3dc3cfb5cce4a58a118181cd0fcc4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da3dc3cfb5cce4a58a118181cd0fcc4c = L.map(
#                 &quot;map_da3dc3cfb5cce4a58a118181cd0fcc4c&quot;,
#                 {
#                     center: [43.72146333333333, 13.220948666666668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5dc9f9a282179ecb2ef1e0820de9e2f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_da3dc3cfb5cce4a58a118181cd0fcc4c);
#
#
#             var marker_6c69dd1f27b43486a5da3783c50c3283 = L.marker(
#                 [43.72119122988505, 13.221280281609193],
#                 {}
#             ).addTo(map_da3dc3cfb5cce4a58a118181cd0fcc4c);
#
#
#             var icon_7e4a3f2cf7a56ed1cbf790e41fae0b9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6c69dd1f27b43486a5da3783c50c3283.setIcon(icon_7e4a3f2cf7a56ed1cbf790e41fae0b9a);
#
#
#             marker_6c69dd1f27b43486a5da3783c50c3283.bindTooltip(
#                 `&lt;div&gt;
#                      mean
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_717e85247a71351f9462be34ddfcaf7d = L.marker(
#                 [43.72119816666667, 13.2212825],
#                 {}
#             ).addTo(map_da3dc3cfb5cce4a58a118181cd0fcc4c);
#
#
#             var icon_972681b81ba9ed123b022af60741b4bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_717e85247a71351f9462be34ddfcaf7d.setIcon(icon_972681b81ba9ed123b022af60741b4bc);
#
#
#             marker_717e85247a71351f9462be34ddfcaf7d.bindTooltip(
#                 `&lt;div&gt;
#                      median
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #Registrazione 4

# %%
mean_4_ll = [np.mean(df_4["latitude_2"]), np.mean(df_4["longitude_2"])]
median_4_ll = [ np.median(df_4["latitude_2"]), np.median(df_4["longitude_2"])]

east,north = convert_dd_to_utm(mean_4_ll[0],mean_4_ll[1])
mean_4_utm = [east,north]
east,north = convert_dd_to_utm(median_4_ll[0],median_4_ll[1])
median_4_utm = [east,north]
variance_4_utm = [ np.var(df_4["utm_east"]), np.var(df_4["utm_north"]) ]

pdop_mean_4 = np.mean(df_4["PDOP"])

map_4 = folium.Map(location=[df_1["latitude_2"].iloc[0], df_1["longitude_2"].iloc[0]], zoom_start=18)

#for x in zip(df_2["latitude_2"].to_list(), df_1["longitude_2"].to_list()):
  #print(x)
#  folium.Marker(location = x, popup = x).add_to(map_1)

folium.Marker(location = mean_4_ll, tooltip= "mean", icon=folium.Icon(color="red")).add_to(map_4)
folium.Marker(location = median_4_ll, tooltip= "median", icon=folium.Icon(color="black")).add_to(map_4)


map_4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15a63f37e5cdeeb03d3230b94bdd3970 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15a63f37e5cdeeb03d3230b94bdd3970&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15a63f37e5cdeeb03d3230b94bdd3970 = L.map(
#                 &quot;map_15a63f37e5cdeeb03d3230b94bdd3970&quot;,
#                 {
#                     center: [43.72146333333333, 13.220948666666668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da885067aefdc7850582600a2a32a113 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_15a63f37e5cdeeb03d3230b94bdd3970);
#
#
#             var marker_f1c5dfca19fce789e19f1f77a928a648 = L.marker(
#                 [43.72123916666667, 13.221242160919546],
#                 {}
#             ).addTo(map_15a63f37e5cdeeb03d3230b94bdd3970);
#
#
#             var icon_70a251b0a341855877621ce15e7d5255 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f1c5dfca19fce789e19f1f77a928a648.setIcon(icon_70a251b0a341855877621ce15e7d5255);
#
#
#             marker_f1c5dfca19fce789e19f1f77a928a648.bindTooltip(
#                 `&lt;div&gt;
#                      mean
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_560a3cd2bdb272e575462b1685c1c7ef = L.marker(
#                 [43.72123833333333, 13.221241166666667],
#                 {}
#             ).addTo(map_15a63f37e5cdeeb03d3230b94bdd3970);
#
#
#             var icon_af46409de9b5fef957ca98d23f216ef9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_560a3cd2bdb272e575462b1685c1c7ef.setIcon(icon_af46409de9b5fef957ca98d23f216ef9);
#
#
#             marker_560a3cd2bdb272e575462b1685c1c7ef.bindTooltip(
#                 `&lt;div&gt;
#                      median
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #Registrazione 5

# %%
mean_5_ll = [np.mean(df_5["latitude_2"]), np.mean(df_5["longitude_2"])]
median_5_ll = [ np.median(df_5["latitude_2"]), np.median(df_5["longitude_2"])]

east,north = convert_dd_to_utm(mean_5_ll[0],mean_5_ll[1])
mean_5_utm = [east,north]
east,north = convert_dd_to_utm(median_5_ll[0],median_5_ll[1])
median_5_utm = [east,north]
variance_5_utm = [ np.var(df_5["utm_east"]), np.var(df_5["utm_north"]) ]

pdop_mean_5 = np.mean(df_5["PDOP"])

map_5 = folium.Map(location=[df_1["latitude_2"].iloc[0], df_1["longitude_2"].iloc[0]], zoom_start=18)

#for x in zip(df_2["latitude_2"].to_list(), df_1["longitude_2"].to_list()):
  #print(x)
#  folium.Marker(location = x, popup = x).add_to(map_1)

folium.Marker(location = mean_5_ll, tooltip= "mean", icon=folium.Icon(color="red")).add_to(map_5)
folium.Marker(location = median_5_ll, tooltip= "median", icon=folium.Icon(color="black")).add_to(map_5)


map_5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04b3c45222a5f8effeacd74a541c4b6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04b3c45222a5f8effeacd74a541c4b6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04b3c45222a5f8effeacd74a541c4b6d = L.map(
#                 &quot;map_04b3c45222a5f8effeacd74a541c4b6d&quot;,
#                 {
#                     center: [43.72146333333333, 13.220948666666668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_243327a32917104d3be94e9e9fa9f9b7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_04b3c45222a5f8effeacd74a541c4b6d);
#
#
#             var marker_756d2f795e8c5344663f52638051962b = L.marker(
#                 [43.7212183045977, 13.22121435632184],
#                 {}
#             ).addTo(map_04b3c45222a5f8effeacd74a541c4b6d);
#
#
#             var icon_c6bdd9eeebecf8ec6c0b2b425938f6a9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_756d2f795e8c5344663f52638051962b.setIcon(icon_c6bdd9eeebecf8ec6c0b2b425938f6a9);
#
#
#             marker_756d2f795e8c5344663f52638051962b.bindTooltip(
#                 `&lt;div&gt;
#                      mean
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_be952f871b0c40f727b99da8783b86e7 = L.marker(
#                 [43.721218666666665, 13.221232833333334],
#                 {}
#             ).addTo(map_04b3c45222a5f8effeacd74a541c4b6d);
#
#
#             var icon_453d8246b2e7a0d9a5c99da48362f8ad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_be952f871b0c40f727b99da8783b86e7.setIcon(icon_453d8246b2e7a0d9a5c99da48362f8ad);
#
#
#             marker_be952f871b0c40f727b99da8783b86e7.bindTooltip(
#                 `&lt;div&gt;
#                      median
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #registrazione 6

# %%
mean_6_ll = [np.mean(df_6["latitude_2"]), np.mean(df_6["longitude_2"])]
median_6_ll = [ np.median(df_6["latitude_2"]), np.median(df_6["longitude_2"])]

east,north = convert_dd_to_utm(mean_6_ll[0],mean_6_ll[1])
mean_6_utm = [east,north]
east,north = convert_dd_to_utm(median_6_ll[0],median_6_ll[1])
median_6_utm = [east,north]
variance_6_utm = [ np.var(df_6["utm_east"]), np.var(df_6["utm_north"]) ]

pdop_mean_6 = np.mean(df_6["PDOP"])

map_6 = folium.Map(location=[df_1["latitude_2"].iloc[0], df_1["longitude_2"].iloc[0]], zoom_start=18)

#for x in zip(df_2["latitude_2"].to_list(), df_1["longitude_2"].to_list()):
  #print(x)
#  folium.Marker(location = x, popup = x).add_to(map_1)

folium.Marker(location = mean_6_ll, tooltip= "mean", icon=folium.Icon(color="red")).add_to(map_6)
folium.Marker(location = median_6_ll, tooltip= "median", icon=folium.Icon(color="black")).add_to(map_6)


map_6
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dae7548969cb35c8cbe693b36d690df2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dae7548969cb35c8cbe693b36d690df2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dae7548969cb35c8cbe693b36d690df2 = L.map(
#                 &quot;map_dae7548969cb35c8cbe693b36d690df2&quot;,
#                 {
#                     center: [43.72146333333333, 13.220948666666668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_259552c5144e0c42bd0d82cd4365b4ae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dae7548969cb35c8cbe693b36d690df2);
#
#
#             var marker_3e54b9fc54f25bd64ea455bd859dcb85 = L.marker(
#                 [43.721192844827584, 13.221100040229887],
#                 {}
#             ).addTo(map_dae7548969cb35c8cbe693b36d690df2);
#
#
#             var icon_9cec82593f8a7b9c225987c8054ee74c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3e54b9fc54f25bd64ea455bd859dcb85.setIcon(icon_9cec82593f8a7b9c225987c8054ee74c);
#
#
#             marker_3e54b9fc54f25bd64ea455bd859dcb85.bindTooltip(
#                 `&lt;div&gt;
#                      mean
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fe27e7167a34425262d55bc3571e1540 = L.marker(
#                 [43.72119833333333, 13.221108166666667],
#                 {}
#             ).addTo(map_dae7548969cb35c8cbe693b36d690df2);
#
#
#             var icon_f8f40666b244319b4e6a09f5affc2984 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fe27e7167a34425262d55bc3571e1540.setIcon(icon_f8f40666b244319b4e6a09f5affc2984);
#
#
#             marker_fe27e7167a34425262d55bc3571e1540.bindTooltip(
#                 `&lt;div&gt;
#                      median
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #Registrazione 7

# %%
mean_7_ll = [np.mean(df_7["latitude_2"]), np.mean(df_7["longitude_2"])]
median_7_ll = [ np.median(df_7["latitude_2"]), np.median(df_7["longitude_2"])]

east,north = convert_dd_to_utm(mean_7_ll[0],mean_7_ll[1])
mean_7_utm = [east,north]
east,north = convert_dd_to_utm(median_7_ll[0],median_7_ll[1])
median_7_utm = [east,north]
variance_7_utm = [ np.var(df_7["utm_east"]), np.var(df_7["utm_north"]) ]

pdop_mean_7 = np.mean(df_7["PDOP"])

map_7 = folium.Map(location=[df_1["latitude_2"].iloc[0], df_1["longitude_2"].iloc[0]], zoom_start=18)

#for x in zip(df_2["latitude_2"].to_list(), df_1["longitude_2"].to_list()):
  #print(x)
#  folium.Marker(location = x, popup = x).add_to(map_1)

folium.Marker(location = mean_7_ll, tooltip= "mean", icon=folium.Icon(color="red")).add_to(map_7)
folium.Marker(location = median_7_ll, tooltip= "median", icon=folium.Icon(color="black")).add_to(map_7)


map_7
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00094a3931b99af38bd0aee77a10716f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00094a3931b99af38bd0aee77a10716f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00094a3931b99af38bd0aee77a10716f = L.map(
#                 &quot;map_00094a3931b99af38bd0aee77a10716f&quot;,
#                 {
#                     center: [43.72146333333333, 13.220948666666668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4c31c880314e6e91c6c7922df7303a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_00094a3931b99af38bd0aee77a10716f);
#
#
#             var marker_88904ddbd269e6fbaeba49cf2cc4f067 = L.marker(
#                 [43.72115854597701, 13.22126608045977],
#                 {}
#             ).addTo(map_00094a3931b99af38bd0aee77a10716f);
#
#
#             var icon_be854ab0132604283427666a4eb2fc6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88904ddbd269e6fbaeba49cf2cc4f067.setIcon(icon_be854ab0132604283427666a4eb2fc6c);
#
#
#             marker_88904ddbd269e6fbaeba49cf2cc4f067.bindTooltip(
#                 `&lt;div&gt;
#                      mean
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7b6dfffb15a82b995972284b2ace4f21 = L.marker(
#                 [43.7211585, 13.221267],
#                 {}
#             ).addTo(map_00094a3931b99af38bd0aee77a10716f);
#
#
#             var icon_a3e176bf7115ffd274f8840bce07b8a9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7b6dfffb15a82b995972284b2ace4f21.setIcon(icon_a3e176bf7115ffd274f8840bce07b8a9);
#
#
#             marker_7b6dfffb15a82b995972284b2ace4f21.bindTooltip(
#                 `&lt;div&gt;
#                      median
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #Mappa tot

# %%
map_tot = folium.Map(location=[df_4["latitude_2"].iloc[0], df_4["longitude_2"].iloc[0]], zoom_start=18)

data_mean = [
    mean_1_ll,
    mean_2_ll,
    mean_3_ll,
    mean_4_ll,
    mean_5_ll,
    mean_6_ll,
    mean_7_ll
]

data_median = [
    median_1_ll,
    median_2_ll,
    median_3_ll,
    median_4_ll,
    median_5_ll,
    median_6_ll,
    median_7_ll
]

#df_filt = df[df["PDOP"] < 3].copy()

#df_filt_2 = df_filt["latitude_2"]

for x in data_mean:
  folium.Marker(location = x, tooltip = x).add_to(map_tot)

#for x in data_median:
#  folium.Marker(location = x, tooltip = x, icon=folium.Icon(color="red")).add_to(map_tot)


map_tot
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8073612ae0f5686ce8411be29039781e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8073612ae0f5686ce8411be29039781e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8073612ae0f5686ce8411be29039781e = L.map(
#                 &quot;map_8073612ae0f5686ce8411be29039781e&quot;,
#                 {
#                     center: [43.721234, 13.2212135],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 18,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcf7fbc3bc5e2fb6dc1cb9f75990e5ec = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8073612ae0f5686ce8411be29039781e);
#
#
#             var marker_728a294300c83ebc7bea63496328369e = L.marker(
#                 [43.72141913218391, 13.220938063218396],
#                 {}
#             ).addTo(map_8073612ae0f5686ce8411be29039781e);
#
#
#             marker_728a294300c83ebc7bea63496328369e.bindTooltip(
#                 `&lt;div&gt;
#                      [43.72141913218391, 13.220938063218396]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fd0b050477ba663218b67f5c02e619ae = L.marker(
#                 [43.721179206896544, 13.221290120689659],
#                 {}
#             ).addTo(map_8073612ae0f5686ce8411be29039781e);
#
#
#             marker_fd0b050477ba663218b67f5c02e619ae.bindTooltip(
#                 `&lt;div&gt;
#                      [43.721179206896544, 13.221290120689659]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6bae4f252e235b8799a73caea15604f4 = L.marker(
#                 [43.72119122988505, 13.221280281609193],
#                 {}
#             ).addTo(map_8073612ae0f5686ce8411be29039781e);
#
#
#             marker_6bae4f252e235b8799a73caea15604f4.bindTooltip(
#                 `&lt;div&gt;
#                      [43.72119122988505, 13.221280281609193]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b8b9fed9011052a28144c272dfa3f34f = L.marker(
#                 [43.72123916666667, 13.221242160919546],
#                 {}
#             ).addTo(map_8073612ae0f5686ce8411be29039781e);
#
#
#             marker_b8b9fed9011052a28144c272dfa3f34f.bindTooltip(
#                 `&lt;div&gt;
#                      [43.72123916666667, 13.221242160919546]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_15917a6a57c7b405aca8e477ed9a3c3f = L.marker(
#                 [43.7212183045977, 13.22121435632184],
#                 {}
#             ).addTo(map_8073612ae0f5686ce8411be29039781e);
#
#
#             marker_15917a6a57c7b405aca8e477ed9a3c3f.bindTooltip(
#                 `&lt;div&gt;
#                      [43.7212183045977, 13.22121435632184]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_63045b2bba0df099d2a4a38d4cce5320 = L.marker(
#                 [43.721192844827584, 13.221100040229887],
#                 {}
#             ).addTo(map_8073612ae0f5686ce8411be29039781e);
#
#
#             marker_63045b2bba0df099d2a4a38d4cce5320.bindTooltip(
#                 `&lt;div&gt;
#                      [43.721192844827584, 13.221100040229887]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_209f59cece66919cdfc2967e17da4f18 = L.marker(
#                 [43.72115854597701, 13.22126608045977],
#                 {}
#             ).addTo(map_8073612ae0f5686ce8411be29039781e);
#
#
#             marker_209f59cece66919cdfc2967e17da4f18.bindTooltip(
#                 `&lt;div&gt;
#                      [43.72115854597701, 13.22126608045977]
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_tot.save("mappa_24_12_2023_pos_2.html")

# %%
data_PDOP = [
    pdop_mean_1,
    pdop_mean_2,
    pdop_mean_3,
    pdop_mean_4,
    pdop_mean_5,
    pdop_mean_6,
    pdop_mean_7
]

utm_variance = [
    variance_1_utm,
    variance_2_utm,
    variance_3_utm,
    variance_4_utm,
    variance_5_utm,
    variance_6_utm,
    variance_7_utm
]

utm_mean_coord = [
    mean_1_utm,
    mean_2_utm,
    mean_3_utm,
    mean_4_utm,
    mean_5_utm,
    mean_6_utm,
    mean_7_utm
]

utm_median_coord = [
    median_1_utm,
    median_2_utm,
    median_3_utm,
    median_4_utm,
    median_5_utm,
    median_6_utm,
    median_7_utm
]

# %%
data_tot = {
    "media_punti" : data_mean,
    "media_punti_utm" : utm_mean_coord,
    "mediana_punti": data_median,
    "mediana_punti_utm" : utm_median_coord,
    "media_PDOP": data_PDOP,
    "varianza_punti(m)": utm_variance
}

# %%
with open("result_24_11_2023_pos_2.json", "w") as file:
  json.dump(data_tot,file, indent = 4)
